# %%
options(warn = -1, tidyverse.quiet = T)

library(tidyverse, warn.conflicts = F, quietly = T)
library(arrow, warn.conflicts = F)
library(cowplot, warn.conflicts = F)
library(yardstick, warn.conflicts = F)
suppressPackageStartupMessages(library(ggmanh, warn.conflicts = F))
suppressPackageStartupMessages(library(hudson, warn.conflicts = F))
library(scattermore)

# %% [markdown]
# # Load data

# %%
raw_comparison_df <- read_parquet("data/gwas_comparison.parquet") %>%
    mutate(
        chromosome = ID %>% 
            str_extract("^.+(?=:)") %>% 
            as.double %>% 
            factor(levels = c(1:22)),
        position = ID %>% str_extract("(?<=:).+$") %>% as.double,
    )

raw_comparison_df %>% head(2)
# Out:
#   mega_type ID           P_mega truth phenotype_id    P        estimate
# 1 Any       11:100009976 0.3977 FALSE MaxGCP (N=350k) 0.254002 FALSE
# 2 Any       11:100009976 0.3977 FALSE MaxGCP (N=15k)  0.872896 FALSE
#   chromosome position
# 1 11         100009976
# 2 11         100009976

# %%
pulm_df <- read_tsv(
        "data/gwas/naive.b_I27.glm.linear", col_select = c("#CHROM", "POS", "P"), 
        show_col_types = F
    ) %>%
    rename(CHROM = `#CHROM`)

pulm_df %>% head(2)
# Out:
#   CHROM POS    P
# 1 1     752566 0.982111
# 2 1     752721 0.995677

# %% [markdown]
# # Manhattan plots

# %%
options(repr.plot.width = 6, repr.plot.height = 3, repr.plot.res = 250)

megastroke_plot <- raw_comparison_df %>%
    filter(mega_type == "Any", phenotype_id == "MaxGCP (N=350k)") %>%
    manhattan_plot(pval.colname = "P_mega", chr.colname = "chromosome", pos.colname = "position")

maxgcp_full_plot <- raw_comparison_df %>%
    filter(mega_type == "Any", phenotype_id == "MaxGCP (N=350k)") %>%
    manhattan_plot(pval.colname = "P", chr.colname = "chromosome", pos.colname = "position")

naive_full_plot <- raw_comparison_df %>%
    filter(mega_type == "Any", phenotype_id == "Naive (N=350k)") %>%
    manhattan_plot(pval.colname = "P", chr.colname = "chromosome", pos.colname = "position")

pulm_plot <- pulm_df %>%
    manhattan_plot(pval.colname = "P", chr.colname = "CHROM", pos.colname = "POS")

# %%
options(repr.plot.width = 6, repr.plot.height = 8, repr.plot.res = 250)

combined_manhattan_plot <- plot_grid(
    megastroke_plot +
        annotate(geom = "text", x = Inf, y = 0, angle = 270, hjust = 1.3, vjust = -0.4, label = "MEGASTROKE") +
        coord_cartesian(clip = "off") +
        theme(
            axis.text.x = element_blank(),
            axis.title.x = element_blank(),
            plot.margin = margin(0.1, 0.5, 0, 0, "cm")
        ),
    maxgcp_full_plot +
        annotate(geom = "text", x = Inf, y = 0, angle = 270, hjust = 1.9, vjust = -0.4, label = "MaxGCP") +
        coord_cartesian(clip = "off") +
        theme(
            axis.text.x = element_blank(),
            axis.title.x = element_blank(),
            plot.margin = margin(0.1, 0.5, 0, 0, "cm")
        ),
    naive_full_plot +
        annotate(geom = "text", x = Inf, y = 0, angle = 270, hjust = 1.48, vjust = -0.4, label = "Stroke (I63)") +
        coord_cartesian(clip = "off") +
        theme(
            axis.text.x = element_blank(),
            axis.title.x = element_blank(),
            plot.margin = margin(0.1, 0.5, 0, 0, "cm")
        ),
    pulm_plot +
        annotate(geom = "text", x = Inf, y = 0, angle = 270, hjust = 1.08, vjust = -0.4, label = "Pulm. heart dis. (I27)") +
        coord_cartesian(clip = "off") +
        theme(
            plot.margin = margin(0.1, 0.5, 0, 0, "cm")
        ),
    align = "v",
    ncol = 1,
    rel_heights = c(1, 1, 1, 1.25)
)

save_plot("img/combined_manhattan.png", combined_manhattan_plot, base_height = 8, base_width = 6, 
          dpi = 400, bg = "white")

combined_manhattan_plot
# Out:
# Coordinate system already present. Adding new coordinate system, which will replace the existing one.
# plot without title

# %% [markdown]
# # "Hudson" plots

# %% [raw]
# raw_comparison_df %>% head(2)

# %% [raw]
# gwas.t <- raw_comparison_df %>%
#     filter(phenotype_id == "MaxGCP (N=350k)") %>%
#     select(SNP = ID, CHR = chromosome, POS = position, pvalue = P)
#
# gwas.b <- raw_comparison_df %>%
#     filter(phenotype_id == "MaxGCP (N=350k)") %>%
#     select(SNP = ID, CHR = chromosome, POS = position, pvalue = P_mega)

# %% [raw]
# gmirror(
#     top = gwas.t,
#     bottom = gwas.b,
#     tline = 0.05,
#     bline = 0.05,
#     toptitle = "MaxGCP",
#     bottomtitle = "MEGASTROKE",
#     highlight_p = c(0.05, 0.05),
#     highlighter = "green"
# )

# %% [markdown]
# # P-values vs P-values directly

# %%
options(repr.plot.width = 7, repr.plot.height = 3.5, repr.plot.res = 250)

raw_pvalue_plot <- raw_comparison_df %>%
    filter(mega_type != "Large artery", phenotype_id %>% str_detect("350")) %>%
    mutate(
        across(c(P, P_mega), ~-log10(.)),
        phenotype_id = phenotype_id %>%
            recode_factor("Naive (N=350k)" = "Naive", "MaxGCP (N=350k)" = "MaxGCP")
            # factor(levels = c("Naive (N=350k)", "MaxGCP (N=350k)"))
    ) %>%
    ggplot(aes(x = P, y = P_mega)) +
    geom_abline(slope = 1, intercept = 0, linetype = "dashed", color = "grey50") +
    geom_scattermore(alpha = 0.25, pointsize = 5) +
    geom_hline(yintercept = -log10(0.05), linetype = "dashed", color = "red", alpha = 0.5) +
    geom_vline(xintercept = -log10(0.05), linetype = "dashed", color = "red", alpha = 0.5) +
    facet_grid(cols = vars(mega_type), rows = vars(phenotype_id), scales = "free") +
    theme_cowplot() +
    panel_border() +
    theme(
        strip.background = element_blank()
    ) +
    xlab(expression("Comparison GWAS"~(-log[10]~p))) +
    ylab(expression("MEGASTROKE"~(-log[10]~p))) +
    scale_x_continuous(n.breaks = 4) +
    scale_y_continuous(n.breaks = 4)

save_plot("img/p_vs_p.png", raw_pvalue_plot, base_width = 7, base_height = 3.5, 
          dpi = 400, bg = "white")

raw_pvalue_plot
# Out:
# plot without title
